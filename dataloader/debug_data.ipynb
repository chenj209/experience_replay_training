# %%
import numpy as np
import matplotlib.pyplot as plt

norm_data_y = np.load("debug_norm_y.npy")
raw_data_y = np.load("debug_raw_y.npy")

# %%
print(norm_data_y.shape)
print(raw_data_y.shape)
# Out:
# (124416, 122)
# (9, 65, 96, 144)
