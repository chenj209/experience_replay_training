# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sample_data = np.load("/Users/jiandachen/Projects/NNCAM_packages/precip_pattern/test_data/00001.npy")

# %%
sample_data2 = np.load("/Users/jiandachen/Projects/NNCAM_packages/precip_pattern/test_data/00003.npy")

# %%
print(sample_data.mean())
print(sample_data2.mean())
# Out:
# 143.87077570951558
# 146.13092749660677

# %%
print(sample_data.shape)
# Out:
# (803, 96, 144)

# %%
print(sample_data.mean())
sample_mean = sample_data.reshape(803,-1).mean(axis=1)
print(sample_mean.shape)
plt.plot(sample_mean)
plt.show()
# Out:
# 3.429780627809504
# (803,)

# %%
print(sample_data2.mean())
sample_mean = sample_data2.reshape(803,-1).mean(axis=1)
print(sample_mean.shape)
plt.plot(sample_mean)
plt.show()
# Out:
# 146.13092749660677
# (803,)
