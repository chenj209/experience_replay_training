# %%
import numpy as np

# %%
test_data = np.load("test_data/35041.npy")
pred_data = np .load("pred_data/35041.npy")

# %%
test_data.shape
# Out:
# (803, 96, 144)

# %%
pred_data.shape
# Out:
# (30, 96, 144)
